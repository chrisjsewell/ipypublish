# %%
from ipypublish.scripts.ipynb_latex_setup import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7d312899154f> in <module>()
# ----> 1 from ipypublish.scripts.ipynb_latex_setup import *
#
# ModuleNotFoundError: No module named 'ipypublish'

# %% [markdown]
# # Markdown

# %% [markdown]
# ## General

# %% [markdown]
# Some markdown text.
#
# A list:
#
# - something
# - something else
#
# A numbered list
#
# 1. something
# 2. something else

# %% [markdown]
# ## References and Citations

# %% [markdown]
# References to \cref{fig:example}, \cref{tbl:example}, \cref{eqn:example_sympy} and \cref{code:example_mpl}.
#
# Referencing multiple items: \cref{fig:example,fig:example_h,fig:example_v}.
#
# A latex citation.\cite{zelenyak_molecular_2016}
#
# A html citation.<cite data-cite="kirkeminde_thermodynamic_2012">(Kirkeminde, 2012)</cite>

# %% [markdown]
# ## Todo notes

# %% [markdown]
# \todo[inline]{an inline todo}
#
# Some text.\todo{a todo in the margins}

# %% [markdown]
# # Images and Figures

# %%
Image('../images/example.jpg',height=400)

# %%
images_hconcat(['../images/example.jpg',
               '../images/example.jpg'],
               width=600, gap=10)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x200 at 0x10B904550>

# %%
images_vconcat(['../images/example.jpg',
               '../images/example.jpg'],
               height=400, gap=10)
# Out:
# <PIL.Image.Image image mode=RGBA size=280x400 at 0x10B9204A8>

# %%
images_gridconcat([[_,_] for _ in ['../images/example.jpg',
               '../images/example.jpg']],
               height=300, vgap=10,hgap=20)
# Out:
# <PIL.Image.Image image mode=RGBA size=443x300 at 0x106AD3358>

# %% [markdown]
# ## Displaying a plot with its code

# %% [markdown]
# A matplotlib figure, with the caption set in the markdowncell above the figure.

# %% [markdown]
# The plotting code for a matplotlib figure (\cref{fig:example_mpl}).

# %%
plt.scatter(np.random.rand(10), np.random.rand(10), 
            label='data label')
plt.ylabel(r'a y label with latex $\alpha$')
plt.legend();

# %%
a = [1,2,3]
a[-1]
# Out:
# 3

# %%
plt.scatter(np.random.rand(10), np.random.rand(10), 
            label='data label')
plt.show()
print('after 1st plot')
from IPython.display import display
display(pd.DataFrame(np.random.rand(3,4),columns=['a','b','c','d']))
print('after table')
plt.scatter(np.random.rand(10), np.random.rand(10), 
            label='data label');
a=b
# Out:
# after 1st plot
#           a         b         c         d
# 0  0.614913  0.335049  0.040124  0.518829
# 1  0.778302  0.774272  0.202736  0.054188
# 2  0.038493  0.100455  0.589906  0.354974
# after table
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-89a52d8c8e8f> in <module>()
#       8 plt.scatter(np.random.rand(10), np.random.rand(10),
#       9             label='data label');
# ---> 10 a=b
#
# NameError: name 'b' is not defined

# %% [markdown]
# # Tables (with pandas)

# %% [markdown]
# The plotting code for a pandas Dataframe table (\cref{tbl:example}).

# %%
df = pd.DataFrame(np.random.rand(3,4),columns=['a','b','c','d'])
df.a = ['$\delta$','x','y']
df.b = ['l','m','n']
df.set_index(['a','b'])
df.round(3)
# Out:
#           a  b      c      d
# 0  $\delta$  l  0.583  0.279
# 1         x  m  0.914  0.021
# 2         y  n  0.333  0.116

# %% [markdown]
# # Equations (with ipython or sympy)

# %%
Latex('$$ a = b+c $$')
# Out:
# $$ a = b+c $$

# %% [markdown]
# The plotting code for a sympy equation (\cref{eqn:example_sympy}).

# %%
f = sym.Function('f')
y,n = sym.symbols(r'y \alpha')
f = y(n)-2*y(n-1/sym.pi)-5*y(n-2)
sym.rsolve(f,y(n),[1,4])
# Out:
#       \alpha ⎛1   2⋅√5⋅ⅈ⎞          \alpha ⎛1   2⋅√5⋅ⅈ⎞
# (√5⋅ⅈ)      ⋅⎜─ - ──────⎟ + (-√5⋅ⅈ)      ⋅⎜─ + ──────⎟
#              ⎝2     5   ⎠                 ⎝2     5   ⎠

# %% [markdown]
# # Embedded HTML

# %% [markdown]
# HTML was created using [ipyvolume](https://ipyvolume.readthedocs.io),
# and will render below in .html type outputs:

# %%
import numpy as np
import ipyvolume.pylab as p3
p3.figure()
u = np.linspace(-10, 10, 25)
x, y = np.meshgrid(u, u)
r = np.sqrt(x**2+y**2).flatten()
x = x.flatten()
y = y.flatten()
time = np.linspace(0, np.pi*2, 15)
z = np.array([(np.cos(r + t) * np.exp(-r/5)) for t in time])
color = np.array([[np.cos(r + t), 1-np.abs(z[i]), 0.1+z[i]*0] for i, t in enumerate(time)])
color = np.transpose(color, (0, 2, 1))
s = p3.scatter(x, z, y, color=color, size=(z+1), marker="sphere")
p3.ylim(-3,3)
p3.show()
p3.save('../html/embed.html')
